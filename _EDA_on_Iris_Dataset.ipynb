# %%
import numpy as np
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Pratham Sankhala\Desktop\Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe().T
# Out:
#                count       mean        std  min    25%    50%     75%    max
# Id             150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# SepalLengthCm  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# SepalWidthCm   150.0   3.054000   0.433594  2.0   2.80   3.00    3.30    4.4
# PetalLengthCm  150.0   3.758667   1.764420  1.0   1.60   4.35    5.10    6.9
# PetalWidthCm   150.0   1.198667   0.763161  0.1   0.30   1.30    1.80    2.5

# %%
df["SepalLengthCm"].mean()
# Out:
# 5.843333333333334

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df["Species"].unique().size
# Out:
# 3

# %%
sns.FacetGrid(df,hue="Species",height=5).map(sns.distplot,"PetalLengthCm").add_legend();

# %%
sns.barplot(x ="Species" , y = "PetalLengthCm" , data = df);

# %%
sns.scatterplot(x="SepalWidthCm" , y="SepalLengthCm", data  = df , color="green")
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='SepalLengthCm'>

# %%
sns.jointplot(x="SepalWidthCm" , y="SepalLengthCm", data  = df , color="green")

# %%
sns.scatterplot(x="SepalWidthCm" , y="SepalLengthCm",hue="Species" , data  = df )
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='SepalLengthCm'>

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sns.countplot(x="Species", data=df)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
sns.violinplot(y="SepalWidthCm", data  = df , color="green")
# Out:
# <Axes: ylabel='SepalWidthCm'>

# %%
sns.displot(df["SepalWidthCm"], bins=16)

# %%
sns.violinplot(x="Species" , y="SepalLengthCm", data = df )
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.jointplot(x="SepalWidthCm" , y="SepalLengthCm", data  = df , color="green")

# %%
sns.jointplot(x="SepalWidthCm" , y="SepalLengthCm", kind = "kde" , data  = df , color="green")

# %%
sns.scatterplot(x="PetalLengthCm" , y="PetalWidthCm",  data  = df , color="green")
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.scatterplot(x="PetalLengthCm" , y="PetalWidthCm",  data  = df , hue="Species")
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.lmplot(x="PetalLengthCm" , y="PetalWidthCm", data=df)

# %%
df[["PetalLengthCm", "PetalWidthCm"]].corr()
# Out:
#                PetalLengthCm  PetalWidthCm
# PetalLengthCm       1.000000      0.962757
# PetalWidthCm        0.962757      1.000000

# %%
df["total_length"] = df["PetalLengthCm"] + df["SepalLengthCm"]

# %%
df["total_length"].mean()
# Out:
# 9.602

# %%
df["total_length"].std()
# Out:
# 2.5191739884121973

# %%
df["SepalLengthCm"].max()
# Out:
# 7.9

# %%
df[(df["SepalLengthCm"] > 5.5) & (df["Species"]== "Iris-setosa")]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
#
#     total_length
# 14           7.0
# 15           7.2
# 18           7.4

# %%
df[(df["SepalLengthCm"] < 5) & (df["Species"]== "Iris-virginica")][["SepalLengthCm" , "SepalWidthCm"]]
# Out:
#      SepalLengthCm  SepalWidthCm
# 106            4.9           2.5

# %%
df.groupby("Species").apply(lambda x: np.mean(x))
# Out:
# Species
# Iris-setosa         7.017000
# Iris-versicolor    16.664667
# Iris-virginica     25.796667
# dtype: float64

# %%
df.groupby("Species")["PetalLengthCm"].apply(lambda x: np.std(x))
# Out:
# Species
# Iris-setosa        0.171767
# Iris-versicolor    0.465188
# Iris-virginica     0.546348
# Name: PetalLengthCm, dtype: float64
